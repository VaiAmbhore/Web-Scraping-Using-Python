# %%
#Import all the libraaries
from bs4 import BeautifulSoup as bs
import requests
import sys
import time
import pandas as pd

# %%
#Website URL to scraping the data
url="https://www.snapdeal.com/products/women-apparel-sarees?sort=plrty"

# %%
try:
    page=requests.get(url)
except Exception as e:
    error_type,error_obj,error_info=sys.exc_inffo()
    print('ERROR FOR LINK:',url)
    prin(error_type,'Line:',error_info.tb_lineno)
    

time.sleep(2)
soup=bs(page.text,'html.parser')
links_1=soup.find_all('span',attrs={'class':'lfloat product-price'})
links_2=soup.find_all('p',attrs={'class':'product-title'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" class="ie ie8 lt-ie9 lt-ie10"> <![endif]-->
# <!--[if IE 9]><html lang="en" class="ie ie9 lt-ie10"> <![endif]-->
# <!--[if IE]><html lang="en" class="ie"><![endif]-->
# <!--[if gt IE 9]><!--><html lang="en"><!--<![endif]-->
# <head prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb# snapdeallog: https://ogp.me/ns/fb/snapdeallog#">
# <link href="https://i1.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://i2.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://i3.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://i4.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://n1.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://n2.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://n3.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://n4.sdlcdn.com" rel="dns-prefetch"/>
# <link href="https://sa.snapdeal.com" rel="dns-prefetch"/>
# <link href="https://search-suggester.snapdeal.com" rel="dns-prefetch"/>
# ...

# %%
links_1
# Out:
# [<span class="lfloat product-price" data-price="329" display-price="329" id="display-price-677188110042">Rs.  329</span>,
#  <span class="lfloat product-price" data-price="575" display-price="575" id="display-price-679961241783">Rs.  575</span>,
#  <span class="lfloat product-price" data-price="725" display-price="725" id="display-price-623416375994">Rs.  725</span>,
#  <span class="lfloat product-price" data-price="599" display-price="599" id="display-price-679774102758">Rs.  599</span>,
#  <span class="lfloat product-price" data-price="299" display-price="299" id="display-price-681485578915">Rs.  299</span>,
#  <span class="lfloat product-price" data-price="359" display-price="359" id="display-price-670708723133">Rs.  359</span>,
#  <span class="lfloat product-price" data-price="329" display-price="329" id="display-price-649781800966">Rs.  329</span>,
#  <span class="lfloat product-price" data-price="519" display-price="519" id="display-price-643796501849">Rs.  519</span>,
# ...

# %%
Price_Col=[]

for i in links_1:
    item=i.text
    Price_Col.append(item)
    
 
    #print('\n')

# %%
links_2
# Out:
# [<p class="product-title" title="Bhakarwadi - Black Silk Blend Saree With Blouse Piece (Pack of 1)">Bhakarwadi - Black Silk Blend Saree With Blouse Piece (Pack of 1)</p>,
#  <p class="product-title" title="Handloom Cotton Silk Yellow With Blouse Piece Saree -">Handloom Cotton Silk Yellow With Blouse Piece Saree -</p>,
#  <p class="product-title" title="Panihari - White Cotton Saree Without Blouse Piece (Pack of 1)">Panihari - White Cotton Saree Without Blouse Piece (Pack of 1)</p>,
#  <p class="product-title" title="Bhuwal - Off White Silk Blend Saree With Blouse Piece (Pack of 1)">Bhuwal - Off White Silk Blend Saree With Blouse Piece (Pack of 1)</p>,
#  <p class="product-title" title="Bhuwal Fashion - Red Cotton Silk Saree With Blouse Piece ( Pack of 1 )">Bhuwal Fashion - Red Cotton Silk Saree With Blouse Piece ( Pack of 1 )</p>,
# ...

# %%
Product_Col=[]

for j in links_2:
    item=j.text
    Product_Col.append(item)
    
    
    #print('\n')

# %%
print(Product_Col)
# Out:
# ['Bhakarwadi - Black Silk Blend Saree With Blouse Piece (Pack of 1)', 'Handloom Cotton Silk Yellow With Blouse Piece Saree -', 'Panihari - White Cotton Saree Without Blouse Piece (Pack of 1)', 'Bhuwal - Off White Silk Blend Saree With Blouse Piece (Pack of 1)', 'Bhuwal Fashion - Red Cotton Silk Saree With Blouse Piece ( Pack of 1 )', 'Gazal Fashions - Multicolor Cotton Saree With Blouse Piece (Pack of 1)', 'Hritika - Red Georgette Saree With Blouse Piece (Pack of 1)', 'Bhuwal Fashion - Blue Cotton Saree With Blouse Piece (Pack of 1)', 'Bhakarwadi - Multicolor Silk Blend Saree With Blouse Piece (Pack of 2)', 'Alexplum - White Silk Blend Saree With Blouse Piece (Pack of 1)', 'Bhakarwadi - Multicolor Silk Blend Saree With Blouse Piece (Pack of 1)', 'Sherine Pink Bhagalpuri Silk Saree', 'NIGHT BLUE Black Cotton Linen Blend Saree - Single', 'Gazal Fashions - Maroon Silk Blend Saree With Blouse Piece (Pack of 1)', 'Gazal Fashions - Peach Net Saree With Blouse Piece ( Pack of 1 )', 'Gazal F
# ...

# %%
print(len(Product_Col))
print(len(Price_Col))
# Out:
# 20
# 20

# %%
#Create Dataframe

df=pd.DataFrame({'Product Name':Product_Col,'Price':Price_Col})
df
# Out:
#                                          Product Name     Price
# 0   Bhakarwadi - Black Silk Blend Saree With Blous...  Rs.  329
# 1   Handloom Cotton Silk Yellow With Blouse Piece ...  Rs.  575
# 2   Panihari - White Cotton Saree Without Blouse P...  Rs.  725
# 3   Bhuwal - Off White Silk Blend Saree With Blous...  Rs.  599
# 4   Bhuwal Fashion - Red Cotton Silk Saree With Bl...  Rs.  299
# 5   Gazal Fashions - Multicolor Cotton Saree With ...  Rs.  359
# 6   Hritika - Red Georgette Saree With Blouse Piec...  Rs.  329
# 7   Bhuwal Fashion - Blue Cotton Saree With Blouse...  Rs.  519
# 8   Bhakarwadi - Multicolor Silk Blend Saree With ...  Rs.  649
# 9   Alexplum - White Silk Blend Saree With Blouse ...  Rs.  349
# 10  Bhakarwadi - Multicolor Silk Blend Saree With ...  Rs.  329
# 11                 Sherine Pink Bhagalpuri Silk Saree  Rs.  279
# 12  NIGHT BLUE Black Cotton Linen Blend Saree - Si...  Rs.  289
# 13  Gazal Fashions - Maroon Silk Blend Saree With ...  Rs.  489
# ...
